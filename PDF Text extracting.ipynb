# %%
# !pip install pdfminer.six
# Out:
# ...
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#      ---------------------------------------- 0.0/5.6 MB 262.6 kB/s eta 0:00:22
#      ---------------------------------------- 0.0/5.6 MB 245.8 kB/s eta 0:00:23
#       --------------------------------------- 0.1/5.6 MB 476.3 kB/s eta 0:00:12
#      - -------------------------------------- 0.2/5.6 MB 654.6 kB/s eta 0:00:09
#      - -------------------------------------- 0.2/5.6 MB 860.2 kB/s eta 0:00:07
#      -- ------------------------------------- 0.4/5.6 MB 1.2 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.6/5.6 MB 1.5 MB/s eta 0:00:04
#      ------ --------------------------------- 0.9/5.6 MB 2.2 MB/s eta 0:00:03
#      ------- -------------------------------- 1.1/5.6 MB 2.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 1.5/5.6 MB 3.0 MB/s eta 0:00:02
# ...

# %%
from pdfminer.high_level import extract_text

text = extract_text("resolucion_no._001-NG-Dinarp-2023.pdf")
print(text)
# Out:
# RESOLUCIÓN No. 001-NG-DINARP-2023
#
# Abg. Angie Karina Jijón Mancheno
#
# DIRECTORA NACIONAL DE REGISTROS PÚBLICOS
#
# CONSIDERANDO:
#
# Que,   el artículo 18 de la Constitución de la República del Ecuador, determina que: “Todas
# las  personas,  en  forma  individual  o  colectiva  tienen  derecho  a:  1.  Buscar,  recibir,  intercambiar,
# producir y difundir información  veraz, verificada, oportuna, contextualizada, plural, sin censura
# previa  acerca  de  los  hechos,  acontecimientos  y  procesos  de  interés  general,  y  con  responsabilidad
# ulterior. 2. Acceder libremente a la información generada en entidades públicas, o en las privadas
# que manejen fondos del Estado o realicen funciones públicas. No existirá reserva de información
# excepto  en  los  casos  expresamente  establecidos  en  la  ley.  En  caso  de  violación  a  los  derechos
# humanos, ninguna entidad pública negará la información.";
#
# ...

# %%
from pdfminer.high_level import extract_text

text2 = extract_text("resolucion_no._001-NG-Dinarp-2023.pdf")
print(repr(text2))
# Out:
# 'RESOLUCIÓN No. 001-NG-DINARP-2023 \n\nAbg. Angie Karina Jijón Mancheno \n\nDIRECTORA NACIONAL DE REGISTROS PÚBLICOS \n\nCONSIDERANDO: \n\nQue,   el artículo 18 de la Constitución de la República del Ecuador, determina que: “Todas \nlas  personas,  en  forma  individual  o  colectiva  tienen  derecho  a:  1.  Buscar,  recibir,  intercambiar, \nproducir y difundir información  veraz, verificada, oportuna, contextualizada, plural, sin censura \nprevia  acerca  de  los  hechos,  acontecimientos  y  procesos  de  interés  general,  y  con  responsabilidad \nulterior. 2. Acceder libremente a la información generada en entidades públicas, o en las privadas \nque manejen fondos del Estado o realicen funciones públicas. No existirá reserva de información \nexcepto  en  los  casos  expresamente  establecidos  en  la  ley.  En  caso  de  violación  a  los  derechos \nhumanos, ninguna entidad pública negará la información."; \n\nQue,   el  artículo  226  de  la  Constitución  de  la  República 
# ...

# %%
file_text = open("textdemo.txt", "w")
# Adding the input data to the HTML file
file_text.write(repr(text2))
file_text.close()

# %%
from io import StringIO
from pdfminer.high_level import extract_text_to_fp
from pdfminer.layout import LAParams

# %%
output_string = StringIO()
with open('resolucion_no._001-NG-Dinarp-2023.pdf', 'rb') as fin:
     extract_text_to_fp(fin, output_string, laparams=LAParams(),
                        output_type='html', codec= None)
print(output_string.getvalue())
# Out:
# <html><head>
# <meta http-equiv="Content-Type" content="text/html">
# </head><body>
# <span style="position:absolute; border: gray 1px solid; left:0px; top:50px; width:595px; height:841px;"></span>
# <div style="position:absolute; top:50px;"><a name="1">Page 1</a></div>
# <div style="position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:185px; top:129px; width:227px; height:12px;"><span style="font-family: Garamond,Bold; font-size:12px">RESOLUCIÓN No. 001-NG-DINARP-2023
# <br></span></div><div style="position:absolute; border: textbox 1px solid; writing-mode:lr-tb; left:208px; top:156px; width:180px; height:12px;"><span style="font-family: Garamond,Bold; font-size:12px">Abg. Angie Karina Jijón Mancheno
# ...

# %%
# Creating the HTML file
file_html = open("demo.html", "w")
# Adding the input data to the HTML file
file_html.write(output_string.getvalue())
file_html.close()

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()
with open('resolucion_no._001-NG-Dinarp-2023.pdf', 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)

print(output_string.getvalue())
# Out:
# RESOLUCIÓN No. 001-NG-DINARP-2023
#
# Abg. Angie Karina Jijón Mancheno
#
# DIRECTORA NACIONAL DE REGISTROS PÚBLICOS
#
# CONSIDERANDO:
#
# Que,   el artículo 18 de la Constitución de la República del Ecuador, determina que: “Todas
# las  personas,  en  forma  individual  o  colectiva  tienen  derecho  a:  1.  Buscar,  recibir,  intercambiar,
# producir y difundir información  veraz, verificada, oportuna, contextualizada, plural, sin censura
# previa  acerca  de  los  hechos,  acontecimientos  y  procesos  de  interés  general,  y  con  responsabilidad
# ulterior. 2. Acceder libremente a la información generada en entidades públicas, o en las privadas
# que manejen fondos del Estado o realicen funciones públicas. No existirá reserva de información
# excepto  en  los  casos  expresamente  establecidos  en  la  ley.  En  caso  de  violación  a  los  derechos
# humanos, ninguna entidad pública negará la información.";
#
# ...
